# %%
import numpy as np

import pandas as pd

from pandas import Series,DataFrame

# %%
import webbrowser
website = 'https://en.wikipedia.org/wiki/NFL_win–loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0    1.0           Dallas Cowboys    511    367      1  0.582
# 1    2.0        Green Bay Packers    730    553     37  0.567
# 2    3.0            Chicago Bears    744    568     42  0.565
# 3    4.0           Miami Dolphins    439    341      4  0.563
# 4    5.0  New England Patriots[b]    476    383      9  0.554
# 5    6.0          New York Giants    684    572     33  0.543
#
#    First NFL Season  Total Games    Division
# 0               1960         860    NFC East
# 1               1921       1,320   NFC North
# 2               1920       1,354   NFC North
# 3               1966         784    AFC East
# 4               1960         868    AFC East
# 5               1925       1,289    NFC East

# %%
nfl_frame.columns
# Out:
# Index([u'Rank ', u'Team ', u'Won ', u'Lost ', u'Tied ', u'Pct. ',
#        u'First NFL Season ', u'Total Games ', u'Division'],
#       dtype='object')

# %%
nfl_frame.columns == 'Rank'
# Out:
# array([False, False, False, False, False, False, False, False, False], dtype=bool)

# %%
nfl_frame.columns[0] == 'Team'
# Out:
# False

# %%
DataFrame(nfl_frame, columns= ['Team','Won'])
# Out:
#    Team  Won
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN
# 4   NaN  NaN
# 5   NaN  NaN

# %%
DataFrame(nfl_frame, columns= ['Okay','Won'])
# Out:
#    Okay  Won
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN
# 4   NaN  NaN
# 5   NaN  NaN

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0    1.0           Dallas Cowboys    511    367      1  0.582
# 1    2.0        Green Bay Packers    730    553     37  0.567
# 2    3.0            Chicago Bears    744    568     42  0.565
# 3    4.0           Miami Dolphins    439    341      4  0.563
# 4    5.0  New England Patriots[b]    476    383      9  0.554
# 5    6.0          New York Giants    684    572     33  0.543
#
#    First NFL Season  Total Games    Division
# 0               1960         860    NFC East
# 1               1921       1,320   NFC North
# 2               1920       1,354   NFC North
# 3               1966         784    AFC East
# 4               1960         868    AFC East
# 5               1925       1,289    NFC East

# %%
nfl_frame.head(3)
# Out:
#    Rank                Team   Won   Lost   Tied   Pct.   First NFL Season   \
# 0    1.0     Dallas Cowboys    511    367      1  0.582               1960
# 1    2.0  Green Bay Packers    730    553     37  0.567               1921
# 2    3.0      Chicago Bears    744    568     42  0.565               1920
#
#   Total Games    Division
# 0         860    NFC East
# 1       1,320   NFC North
# 2       1,354   NFC North

# %%
nfl_frame.ix[4]
# Out:
# Rank                                        5
# Team                 New England Patriots[b]
# Won                                       476
# Lost                                      383
# Tied                                        9
# Pct.                                    0.554
# First NFL Season                         1960
# Total Games                              868
# Division                             AFC East
# Name: 4, dtype: object

# %%
nfl_frame['okay']= "Levis"

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0    1.0           Dallas Cowboys    511    367      1  0.582
# 1    2.0        Green Bay Packers    730    553     37  0.567
# 2    3.0            Chicago Bears    744    568     42  0.565
# 3    4.0           Miami Dolphins    439    341      4  0.563
# 4    5.0  New England Patriots[b]    476    383      9  0.554
# 5    6.0          New York Giants    684    572     33  0.543
#
#    First NFL Season  Total Games    Division   okay
# 0               1960         860    NFC East  Levis
# 1               1921       1,320   NFC North  Levis
# 2               1920       1,354   NFC North  Levis
# 3               1966         784    AFC East  Levis
# 4               1960         868    AFC East  Levis
# 5               1925       1,289    NFC East  Levis

# %%
nfl_frame['okay']= np.arange(6)

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0    1.0           Dallas Cowboys    511    367      1  0.582
# 1    2.0        Green Bay Packers    730    553     37  0.567
# 2    3.0            Chicago Bears    744    568     42  0.565
# 3    4.0           Miami Dolphins    439    341      4  0.563
# 4    5.0  New England Patriots[b]    476    383      9  0.554
# 5    6.0          New York Giants    684    572     33  0.543
#
#    First NFL Season  Total Games    Division  okay
# 0               1960         860    NFC East     0
# 1               1921       1,320   NFC North     1
# 2               1920       1,354   NFC North     2
# 3               1966         784    AFC East     3
# 4               1960         868    AFC East     4
# 5               1925       1,289    NFC East     5

# %%
okay= Series(["oh yeah", "ma ka bachhha"], index=[2,3])

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0    1.0           Dallas Cowboys    511    367      1  0.582
# 1    2.0        Green Bay Packers    730    553     37  0.567
# 2    3.0            Chicago Bears    744    568     42  0.565
# 3    4.0           Miami Dolphins    439    341      4  0.563
# 4    5.0  New England Patriots[b]    476    383      9  0.554
# 5    6.0          New York Giants    684    572     33  0.543
#
#    First NFL Season  Total Games    Division  okay
# 0               1960         860    NFC East     0
# 1               1921       1,320   NFC North     1
# 2               1920       1,354   NFC North     2
# 3               1966         784    AFC East     3
# 4               1960         868    AFC East     4
# 5               1925       1,289    NFC East     5

# %%
okay
# Out:
# 2          oh yeah
# 3    ma ka bachhha
# dtype: object

# %%
nfl_frame['okay ']= okay

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0    1.0           Dallas Cowboys    511    367      1  0.582
# 1    2.0        Green Bay Packers    730    553     37  0.567
# 2    3.0            Chicago Bears    744    568     42  0.565
# 3    4.0           Miami Dolphins    439    341      4  0.563
# 4    5.0  New England Patriots[b]    476    383      9  0.554
# 5    6.0          New York Giants    684    572     33  0.543
#
#    First NFL Season  Total Games    Division  okay          okay
# 0               1960         860    NFC East     0            NaN
# 1               1921       1,320   NFC North     1            NaN
# 2               1920       1,354   NFC North     2        oh yeah
# 3               1966         784    AFC East     3  ma ka bachhha
# 4               1960         868    AFC East     4            NaN
# 5               1925       1,289    NFC East     5            NaN

# %%
del nfl_frame.columns[10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-2e230c5d4c34> in <module>()
# ----> 1 del nfl_frame.columns[10]
#
# AttributeError: __delitem__

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0    1.0           Dallas Cowboys    511    367      1  0.582
# 1    2.0        Green Bay Packers    730    553     37  0.567
# 2    3.0            Chicago Bears    744    568     42  0.565
# 3    4.0           Miami Dolphins    439    341      4  0.563
# 4    5.0  New England Patriots[b]    476    383      9  0.554
# 5    6.0          New York Giants    684    572     33  0.543
#
#    First NFL Season  Total Games    Division          okay
# 0               1960         860    NFC East            NaN
# 1               1921       1,320   NFC North            NaN
# 2               1920       1,354   NFC North        oh yeah
# 3               1966         784    AFC East  ma ka bachhha
# 4               1960         868    AFC East            NaN
# 5               1925       1,289    NFC East            NaN

# %%
data = {'City':[1,2,5,9],'Popolution':['sf','gf','gh','Yahan thi problem']}

# %%
new_frame = DataFrame(data)

# %%
data
# Out:
# {'City': [1, 2, 5, 9], 'Popolution': ['sf', 'gf', 'gh']}

# %%
new_frame
# Out:
#    City         Popolution
# 0     1                 sf
# 1     2                 gf
# 2     5                 gh
# 3     9  Yahan thi problem
