# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# %%
from numpy.random import randn

# %%
from scipy import stats

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
d1=randn(100)

# %%
plt.hist(d1)
# Out:
# (array([  5.,   7.,  15.,  24.,  16.,  10.,  11.,   9.,   2.,   1.]),
#  array([-2.42858533, -1.86839028, -1.30819522, -0.74800017, -0.18780512,
#          0.37238993,  0.93258498,  1.49278003,  2.05297508,  2.61317013,
#          3.17336518]),
#  <a list of 10 Patch objects>)

# %%
d2= randn(80)
plt.hist(d2,color='indianred')
# Out:
# (array([  2.,   2.,   8.,  13.,  17.,  12.,   8.,   9.,   4.,   5.]),
#  array([-2.26908228, -1.81462924, -1.36017621, -0.90572318, -0.45127014,
#          0.00318289,  0.45763592,  0.91208895,  1.36654199,  1.82099502,
#          2.27544805]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(d1,normed=True, color = 'blue',alpha=0.5)
plt.hist(d2,normed=True,color= 'indianred',alpha=0.5)
# Out:
# (array([ 0.05501119,  0.05501119,  0.22004474,  0.3575727 ,  0.46759507,
#          0.33006711,  0.22004474,  0.24755033,  0.11002237,  0.13752796]),
#  array([-2.26908228, -1.81462924, -1.36017621, -0.90572318, -0.45127014,
#          0.00318289,  0.45763592,  0.91208895,  1.36654199,  1.82099502,
#          2.27544805]),
#  <a list of 10 Patch objects>)

# %%
d=randn(1000)
f=randn(1000)

# %%
sns.jointplot(d,f)

# %%
sns.jointplot(d,f,kind='hex')
