# %%
# The normal imports
import pandas as pd
import numpy as np
from numpy.random import randn

# Import the stats library from numpy
from scipy import stats

# Import plotting modules
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Make plots appear in iPython notebook
# %matplotlib inline

# %%
f=sns.load_dataset('flights')

# %%
f.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
f=f.pivot('month','year','passengers')
f
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(f)

# %%
sns.heatmap(f,annot=True)

# %%
sns.heatmap(f,center=f.loc['January',1955])

# %%
fl,(axis1,axis2)= plt.subplots(2,1)
yflights=  f.sum([year])
years=pd.Series(y.index.values)
y=pd.DataFrame(years)

flights=pd.Series(y.index.values)
flights=pd.DataFrame(flights)

year = pd.concat((y,flights),axis=1)
y.columns=['Year','FLight']

sns.barplot('Year',y='Flight',data=y,ax=axis1)
sns.heatmap(f,cmap='Blues',ax=axis2,cbar_kws = {'orientation':'horizontal'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-4462c8971277> in <module>()
#       1 fl,(axis1,axis2)= plt.subplots(2,1)
# ----> 2 yflights=  f.sum([year])
#       3 years=pd.Series(y.index.values)
#       4 y=pd.DataFrame(years)
#       5
#
# AttributeError: 'Figure' object has no attribute 'sum'

# %%
f,(axis1,axis2) = plt.subplots(2,1)
yearly_flights = f.sum(axis=1)
years = pd.Series(yearly_flights.index.values)
years = pd.DataFrame(years)
flights = pd.Series(yearly_flights.values)
flights = pd.DataFrame(flights)
year_dframe = pd.concat((years,flights),axis=1)
year_dframe.columns = ['Year','Flights']

sns.barplot("Year",y='Flights',data=year_dframe,ax=axis1)
sns.heatmap(flight_dframe,cmap='Blues',ax=axis2,cbar_kws={'orientation':'horizontal'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-905ed3dfc5f0> in <module>()
#       2
#       3 f,(axis1,axis2) = plt.subplots(2,1)
# ----> 4 yearly_flights = f.sum(axis=1)
#       5 years = pd.Series(yearly_flights.index.values)
#       6 years = pd.DataFrame(years)
#
# AttributeError: 'Figure' object has no attribute 'sum'

# %%
#No sum bro

# %%
sns.clustermap(f)

# %%
sns.clustermap(f,col_cluster=False)

# %%
sns.clustermap(f,standard_scale=1)

# %%
sns.clustermap(f,standard_scale=0)

# %%
sns.clustermap(f,z_score=1)
